# %% [markdown]
# ## 1. Import Libraries and Load Data

# %%
import json
import numpy as np
from collections import defaultdict
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage

# %%
with open('actual_pr_reviewer_assignments.json', 'r', encoding='utf-8') as f:
    actual_data = json.load(f)

with open('all_pr_reviewer_assignments.json', 'r', encoding='utf-8') as f:
    predicted_data = json.load(f)

print(f"Total PRs in actual data: {len(actual_data['pr_reviewer_assignments'])}")
print(f"Total PRs in predicted data: {len(predicted_data['pr_assignments'])}")
# Out:
# Total PRs in actual data: 39
# Total PRs in predicted data: 39

# %% [markdown]
# ## 2. Data Preparation

# %%
actual_reviewers = {}
predicted_reviewers = {}

for pr in actual_data['pr_reviewer_assignments']:
    pr_number = pr['pr_number']
    actual_reviewers[pr_number] = pr['unique_reviewers']

for pr in predicted_data['pr_assignments']:
    pr_number = pr['pr_number']
    
    # Extract top-3 reviewer names from the detailed predictions
    if 'top_3_reviewers' in pr and pr['top_3_reviewers']:
        top_3_names = [reviewer['reviewer_name'] for reviewer in pr['top_3_reviewers']]
        predicted_reviewers[pr_number] = top_3_names
    else:
        # Fallback to assigned_reviewer if top_3_reviewers is not available
        predicted_reviewers[pr_number] = [pr['assigned_reviewer']] if pr.get('assigned_reviewer') else []

common_prs = set(actual_reviewers.keys()) & set(predicted_reviewers.keys())

# %% [markdown]
# ## 3. Comprehensive Metric Calculation Functions

# %%
def calculate_top_k_accuracy(actual, predicted, k=1):
    if not common_prs:
        return 0.0
    
    hits = 0
    total = 0
    
    for pr_num in common_prs:
        actual_revs = set(actual[pr_num])
        pred_revs = predicted[pr_num][:k]
        
        if any(rev in actual_revs for rev in pred_revs):
            hits += 1
        total += 1
    
    return (hits / total) * 100 if total > 0 else 0.0

# %%
# ==================== PRECISION@K ====================
def calculate_precision_at_k(actual, predicted, k):
    """
    Precision@k = (# of recommended items @k that are relevant) / k
    """
    actual_set = set(actual)
    pred_k = predicted[:k]
    
    if k == 0:
        return 0.0
    
    relevant_at_k = sum(1 for p in pred_k if p in actual_set)
    return relevant_at_k / k

def calculate_avg_precision_at_k(actual_dict, predicted_dict, k):
    """Calculate average Precision@k across all PRs"""
    if not common_prs:
        return 0.0
    
    precision_scores = []
    for pr_num in common_prs:
        precision = calculate_precision_at_k(
            actual_dict[pr_num],
            predicted_dict[pr_num],
            k
        )
        precision_scores.append(precision)
    
    return np.mean(precision_scores) * 100

# %%
# ==================== RECALL@K ====================
def calculate_recall_at_k(actual, predicted, k):
    """
    Recall@k = (# of recommended items @k that are relevant) / (total # of relevant items)
    """
    actual_set = set(actual)
    pred_k = predicted[:k]
    
    if len(actual_set) == 0:
        return 0.0
    
    relevant_at_k = sum(1 for p in pred_k if p in actual_set)
    return relevant_at_k / len(actual_set)

def calculate_avg_recall_at_k(actual_dict, predicted_dict, k):
    """Calculate average Recall@k across all PRs"""
    if not common_prs:
        return 0.0
    
    recall_scores = []
    for pr_num in common_prs:
        recall = calculate_recall_at_k(
            actual_dict[pr_num],
            predicted_dict[pr_num],
            k
        )
        recall_scores.append(recall)
    
    return np.mean(recall_scores) * 100

# %%
# ==================== F1-SCORE@K ====================
def calculate_f1_at_k(actual, predicted, k):
    """
    F1@k = 2 * (Precision@k * Recall@k) / (Precision@k + Recall@k)
    """
    precision = calculate_precision_at_k(actual, predicted, k)
    recall = calculate_recall_at_k(actual, predicted, k)
    
    if precision + recall == 0:
        return 0.0
    
    return 2 * (precision * recall) / (precision + recall)

def calculate_avg_f1_at_k(actual_dict, predicted_dict, k):
    """Calculate average F1@k across all PRs"""
    if not common_prs:
        return 0.0
    
    f1_scores = []
    for pr_num in common_prs:
        f1 = calculate_f1_at_k(
            actual_dict[pr_num],
            predicted_dict[pr_num],
            k
        )
        f1_scores.append(f1)
    
    return np.mean(f1_scores) * 100

# %%
# ==================== HIT@K ====================
def calculate_hit_at_k(actual, predicted, k):
    """
    Hit@k = 1 if at least one relevant item is in top-k, else 0
    """
    actual_set = set(actual)
    pred_k = predicted[:k]
    
    return 1.0 if any(p in actual_set for p in pred_k) else 0.0

def calculate_avg_hit_at_k(actual_dict, predicted_dict, k):
    """Calculate average Hit@k across all PRs (same as Top-k Accuracy)"""
    if not common_prs:
        return 0.0
    
    hit_scores = []
    for pr_num in common_prs:
        hit = calculate_hit_at_k(
            actual_dict[pr_num],
            predicted_dict[pr_num],
            k
        )
        hit_scores.append(hit)
    
    return np.mean(hit_scores) * 100

# %%
def calculate_average_precision_at_k(actual, predicted, k=5):
    actual_set = set(actual)
    pred_k = predicted[:k]
    
    if len(actual_set) == 0:
        return 0.0
    
    score = 0.0
    num_hits = 0.0
    
    for i, p in enumerate(pred_k):
        if p in actual_set:
            num_hits += 1.0
            score += num_hits / (i + 1.0)
    
    return score / min(len(actual_set), k)

def calculate_map_at_k(actual, predicted, k=5):
    if not common_prs:
        return 0.0
    
    ap_scores = []
    
    for pr_num in common_prs:
        ap = calculate_average_precision_at_k(
            actual[pr_num], 
            predicted[pr_num], 
            k
        )
        ap_scores.append(ap)
    
    return np.mean(ap_scores) * 100

# %%
def calculate_reciprocal_rank(actual, predicted):
    actual_set = set(actual)
    
    for i, p in enumerate(predicted):
        if p in actual_set:
            return 1.0 / (i + 1.0)
    
    return 0.0

def calculate_mrr(actual, predicted):
    if not common_prs:
        return 0.0
    
    rr_scores = []
    
    for pr_num in common_prs:
        rr = calculate_reciprocal_rank(
            actual[pr_num], 
            predicted[pr_num]
        )
        rr_scores.append(rr)
    
    return np.mean(rr_scores)

# %%
# ==================== DCG & NDCG ====================
def calculate_dcg_at_k(actual, predicted, k):
    """
    DCG@k = sum(rel_i / log2(i + 1)) for i in range(k)
    rel_i = 1 if predicted[i] is relevant, else 0
    """
    actual_set = set(actual)
    pred_k = predicted[:k]
    
    dcg = 0.0
    for i, p in enumerate(pred_k):
        if p in actual_set:
            # relevance = 1 for relevant items
            dcg += 1.0 / np.log2(i + 2)  # i+2 because log2(1) = 0
    
    return dcg

def calculate_idcg_at_k(actual, k):
    """
    IDCG@k = DCG of ideal ranking (all relevant items first)
    """
    num_relevant = min(len(actual), k)
    idcg = 0.0
    for i in range(num_relevant):
        idcg += 1.0 / np.log2(i + 2)
    
    return idcg

def calculate_ndcg_at_k(actual, predicted, k):
    """
    NDCG@k = DCG@k / IDCG@k
    """
    dcg = calculate_dcg_at_k(actual, predicted, k)
    idcg = calculate_idcg_at_k(actual, k)
    
    if idcg == 0:
        return 0.0
    
    return dcg / idcg

def calculate_avg_dcg_at_k(actual_dict, predicted_dict, k):
    """Calculate average DCG@k across all PRs"""
    if not common_prs:
        return 0.0
    
    dcg_scores = []
    for pr_num in common_prs:
        dcg = calculate_dcg_at_k(
            actual_dict[pr_num],
            predicted_dict[pr_num],
            k
        )
        dcg_scores.append(dcg)
    
    return np.mean(dcg_scores)

def calculate_avg_ndcg_at_k(actual_dict, predicted_dict, k):
    """Calculate average NDCG@k across all PRs"""
    if not common_prs:
        return 0.0
    
    ndcg_scores = []
    for pr_num in common_prs:
        ndcg = calculate_ndcg_at_k(
            actual_dict[pr_num],
            predicted_dict[pr_num],
            k
        )
        ndcg_scores.append(ndcg)
    
    return np.mean(ndcg_scores) * 100

# %%
def calculate_stability_metrics(actual, predicted):
    # Get all unique reviewers
    all_actual_reviewers = set()
    all_predicted_reviewers = set()
    
    for pr_num in common_prs:
        all_actual_reviewers.update(actual[pr_num])
        all_predicted_reviewers.update(predicted[pr_num])
    
    # Coverage: How many actual reviewers were predicted at least once
    coverage = len(all_actual_reviewers & all_predicted_reviewers) / len(all_actual_reviewers) if all_actual_reviewers else 0
    
    # Diversity ratio
    diversity_ratio = len(all_predicted_reviewers) / len(all_actual_reviewers) if all_actual_reviewers else 0
    
    # Exact match rate (predicted reviewer exactly matches one of the actual reviewers)
    exact_matches = sum(1 for pr_num in common_prs if set(predicted[pr_num]) & set(actual[pr_num]))
    exact_match_rate = (exact_matches / len(common_prs)) * 100 if common_prs else 0
    
    return {
        'coverage': coverage * 100,
        'diversity_ratio': diversity_ratio,
        'exact_match_rate': exact_match_rate,
        'unique_actual_reviewers': len(all_actual_reviewers),
        'unique_predicted_reviewers': len(all_predicted_reviewers)
    }

# %% [markdown]
# ## 4. Calculate All Metrics

# %%
# ==================== CALCULATE ALL METRICS ====================

# Precision@k
precision_at_1 = calculate_avg_precision_at_k(actual_reviewers, predicted_reviewers, k=1)
precision_at_3 = calculate_avg_precision_at_k(actual_reviewers, predicted_reviewers, k=3)
precision_at_5 = calculate_avg_precision_at_k(actual_reviewers, predicted_reviewers, k=5)
precision_at_10 = calculate_avg_precision_at_k(actual_reviewers, predicted_reviewers, k=10)

# Recall@k
recall_at_1 = calculate_avg_recall_at_k(actual_reviewers, predicted_reviewers, k=1)
recall_at_3 = calculate_avg_recall_at_k(actual_reviewers, predicted_reviewers, k=3)
recall_at_5 = calculate_avg_recall_at_k(actual_reviewers, predicted_reviewers, k=5)
recall_at_10 = calculate_avg_recall_at_k(actual_reviewers, predicted_reviewers, k=10)

# F1-Score@k
f1_at_1 = calculate_avg_f1_at_k(actual_reviewers, predicted_reviewers, k=1)
f1_at_3 = calculate_avg_f1_at_k(actual_reviewers, predicted_reviewers, k=3)
f1_at_5 = calculate_avg_f1_at_k(actual_reviewers, predicted_reviewers, k=5)
f1_at_10 = calculate_avg_f1_at_k(actual_reviewers, predicted_reviewers, k=10)

# Hit@k (Top-k Accuracy)
hit_at_1 = calculate_avg_hit_at_k(actual_reviewers, predicted_reviewers, k=1)
hit_at_3 = calculate_avg_hit_at_k(actual_reviewers, predicted_reviewers, k=3)
hit_at_5 = calculate_avg_hit_at_k(actual_reviewers, predicted_reviewers, k=5)
hit_at_10 = calculate_avg_hit_at_k(actual_reviewers, predicted_reviewers, k=10)

# MRR (Mean Reciprocal Rank)
mrr = calculate_mrr(actual_reviewers, predicted_reviewers)

# MAP@k (Mean Average Precision)
map_at_1 = calculate_map_at_k(actual_reviewers, predicted_reviewers, k=1)
map_at_3 = calculate_map_at_k(actual_reviewers, predicted_reviewers, k=3)
map_at_5 = calculate_map_at_k(actual_reviewers, predicted_reviewers, k=5)
map_at_10 = calculate_map_at_k(actual_reviewers, predicted_reviewers, k=10)

# DCG@k (Discounted Cumulative Gain)
dcg_at_1 = calculate_avg_dcg_at_k(actual_reviewers, predicted_reviewers, k=1)
dcg_at_3 = calculate_avg_dcg_at_k(actual_reviewers, predicted_reviewers, k=3)
dcg_at_5 = calculate_avg_dcg_at_k(actual_reviewers, predicted_reviewers, k=5)
dcg_at_10 = calculate_avg_dcg_at_k(actual_reviewers, predicted_reviewers, k=10)

# NDCG@k (Normalized Discounted Cumulative Gain)
ndcg_at_1 = calculate_avg_ndcg_at_k(actual_reviewers, predicted_reviewers, k=1)
ndcg_at_3 = calculate_avg_ndcg_at_k(actual_reviewers, predicted_reviewers, k=3)
ndcg_at_5 = calculate_avg_ndcg_at_k(actual_reviewers, predicted_reviewers, k=5)
ndcg_at_10 = calculate_avg_ndcg_at_k(actual_reviewers, predicted_reviewers, k=10)

# Stability Metrics
stability = calculate_stability_metrics(actual_reviewers, predicted_reviewers)

print("✅ All metrics calculated successfully!")
# Out:
# ✅ All metrics calculated successfully!

# %%
print("="*80)
print("PR REVIEWER ASSIGNMENT - COMPREHENSIVE EVALUATION METRICS")
print("="*80)
print(f"\nTotal PRs Evaluated: {len(common_prs)}")
print("\n" + "="*80)

# ==================== PRECISION@K ====================
print("\n📊 PRECISION@K")
print("-"*80)
print(f"Precision@1:  {precision_at_1:.2f}%")
print(f"Precision@3:  {precision_at_3:.2f}%")
print(f"Precision@5:  {precision_at_5:.2f}%")
print(f"Precision@10: {precision_at_10:.2f}%")

# ==================== RECALL@K ====================
print("\n📊 RECALL@K")
print("-"*80)
print(f"Recall@1:  {recall_at_1:.2f}%")
print(f"Recall@3:  {recall_at_3:.2f}%")
print(f"Recall@5:  {recall_at_5:.2f}%")
print(f"Recall@10: {recall_at_10:.2f}%")

# ==================== F1-SCORE@K ====================
print("\n📊 F1-SCORE@K")
print("-"*80)
print(f"F1@1:  {f1_at_1:.2f}%")
print(f"F1@3:  {f1_at_3:.2f}%")
print(f"F1@5:  {f1_at_5:.2f}%")
print(f"F1@10: {f1_at_10:.2f}%")

# ==================== HIT@K (Top-k Accuracy) ====================
print("\n📊 HIT@K (Top-k Accuracy)")
print("-"*80)
print(f"Hit@1:  {hit_at_1:.2f}%")
print(f"Hit@3:  {hit_at_3:.2f}%")
print(f"Hit@5:  {hit_at_5:.2f}%")
print(f"Hit@10: {hit_at_10:.2f}%")

# ==================== MRR ====================
print("\n📊 MEAN RECIPROCAL RANK (MRR)")
print("-"*80)
print(f"MRR:       {mrr:.4f}")
print(f"MRR (%):   {mrr*100:.2f}%")

# ==================== MAP@K ====================
print("\n📊 MEAN AVERAGE PRECISION (MAP@K)")
print("-"*80)
print(f"MAP@1:  {map_at_1:.2f}%")
print(f"MAP@3:  {map_at_3:.2f}%")
print(f"MAP@5:  {map_at_5:.2f}%")
print(f"MAP@10: {map_at_10:.2f}%")

# ==================== DCG@K ====================
print("\n📊 DISCOUNTED CUMULATIVE GAIN (DCG@K)")
print("-"*80)
print(f"DCG@1:  {dcg_at_1:.4f}")
print(f"DCG@3:  {dcg_at_3:.4f}")
print(f"DCG@5:  {dcg_at_5:.4f}")
print(f"DCG@10: {dcg_at_10:.4f}")

# ==================== NDCG@K ====================
print("\n📊 NORMALIZED DISCOUNTED CUMULATIVE GAIN (NDCG@K)")
print("-"*80)
print(f"NDCG@1:  {ndcg_at_1:.2f}%")
print(f"NDCG@3:  {ndcg_at_3:.2f}%")
print(f"NDCG@5:  {ndcg_at_5:.2f}%")
print(f"NDCG@10: {ndcg_at_10:.2f}%")

# ==================== STABILITY METRICS ====================
print("\n📊 STABILITY METRICS")
print("-"*80)
print(f"Coverage (Actual reviewers in predictions): {stability['coverage']:.2f}%")
print(f"Exact Match Rate:                           {stability['exact_match_rate']:.2f}%")
print(f"Diversity Ratio:                            {stability['diversity_ratio']:.2f}")
print(f"Unique Actual Reviewers:                    {stability['unique_actual_reviewers']}")
print(f"Unique Predicted Reviewers:                 {stability['unique_predicted_reviewers']}")

print("\n" + "="*80)
print("✅ Evaluation Complete!")
print("="*80)
# Out:
# ================================================================================
# PR REVIEWER ASSIGNMENT - COMPREHENSIVE EVALUATION METRICS
# ================================================================================
#
# Total PRs Evaluated: 39
#
# ================================================================================
#
# 📊 PRECISION@K
# --------------------------------------------------------------------------------
# Precision@1:  20.51%
# Precision@3:  15.38%
# Precision@5:  9.23%
# Precision@10: 4.62%
#
# 📊 RECALL@K
# --------------------------------------------------------------------------------
# Recall@1:  13.46%
# Recall@3:  30.34%
# Recall@5:  30.34%
# Recall@10: 30.34%
#
# 📊 F1-SCORE@K
# --------------------------------------------------------------------------------
# F1@1:  15.56%
# F1@3:  19.50%
# F1@5:  13.62%
# F1@10: 7.81%
#
# 📊 HIT@K (Top-k Accuracy)
# --------------------------------------------------------------------------------
# Hit@1:  20.51%
# Hit@3:  43.59%
# Hit@5:  43.59%
# Hit@10: 43.59%
#
# 📊 MEAN RECIPROCAL RANK (MRR)
# --------------------------------------------------------------------------------
# MRR:       0.3077
# MRR (%):   30.77%
#
# 📊 MEAN AVERAGE PRECISION (MAP@K)
# --------------------------------------------------------------------------------
# MAP@1:  20.51%
# MAP@3:  22.08%
# MAP@5:  21.79%
# MAP@10: 21.79%
#
# 📊 DISCOUNTED CUMULATIVE GAIN (DCG@K)
# --------------------------------------------------------------------------------
# DCG@1:  0.2051
# DCG@3:  0.3568
# DCG@5:  0.3568
# DCG@10: 0.3568
#
# 📊 NORMALIZED DISCOUNTED CUMULATIVE GAIN (NDCG@K)
# --------------------------------------------------------------------------------
# NDCG@1:  20.51%
# NDCG@3:  26.44%
# NDCG@5:  26.14%
# NDCG@10: 26.14%
#
# 📊 STABILITY METRICS
# --------------------------------------------------------------------------------
# Coverage (Actual reviewers in predictions): 10.26%
# Exact Match Rate:                           43.59%
# Diversity Ratio:                            0.28
# Unique Actual Reviewers:                    39
# Unique Predicted Reviewers:                 11
#
# ================================================================================
# ✅ Evaluation Complete!
# ================================================================================

# %%
# ==================== METRICS SUMMARY TABLE ====================
import pandas as pd

metrics_summary = pd.DataFrame({
    'k': [1, 3, 5, 10],
    'Precision@k': [precision_at_1, precision_at_3, precision_at_5, precision_at_10],
    'Recall@k': [recall_at_1, recall_at_3, recall_at_5, recall_at_10],
    'F1@k': [f1_at_1, f1_at_3, f1_at_5, f1_at_10],
    'Hit@k': [hit_at_1, hit_at_3, hit_at_5, hit_at_10],
    'MAP@k': [map_at_1, map_at_3, map_at_5, map_at_10],
    'NDCG@k': [ndcg_at_1, ndcg_at_3, ndcg_at_5, ndcg_at_10]
})

print("\n" + "="*80)
print("📊 METRICS SUMMARY TABLE")
print("="*80)
print(metrics_summary.to_string(index=False))
print("\n" + "="*80)
# Out:
# ================================================================================
# 📊 METRICS SUMMARY TABLE
# ================================================================================
#  k  Precision@k  Recall@k      F1@k     Hit@k     MAP@k    NDCG@k
#  1    20.512821 13.461538 15.555556 20.512821 20.512821 20.512821
#  3    15.384615 30.341880 19.499389 43.589744 22.079772 26.442333
#  5     9.230769 30.341880 13.624339 43.589744 21.794872 26.138877
# 10     4.615385 30.341880  7.809285 43.589744 21.794872 26.138877
#
# ================================================================================

# %%
# ==================== ANALYZE MULTIPLE REVIEWERS HANDLING ====================
print("🔍 ANALYZING MULTIPLE REVIEWERS IN EVALUATION")
print("=" * 80)

# Analyze the distribution of actual reviewers per PR
reviewer_count_distribution = {}
multiple_reviewer_examples = []

for pr_num in common_prs:
    actual_revs = actual_reviewers[pr_num]
    num_reviewers = len(actual_revs)
    
    # Count distribution
    reviewer_count_distribution[num_reviewers] = reviewer_count_distribution.get(num_reviewers, 0) + 1
    
    # Collect examples of PRs with multiple reviewers
    if num_reviewers > 1:
        multiple_reviewer_examples.append({
            'pr_number': pr_num,
            'actual_reviewers': actual_revs,
            'predicted_top3': predicted_reviewers[pr_num][:3],
            'num_actual': num_reviewers
        })

print(f"📊 REVIEWER COUNT DISTRIBUTION:")
total_prs = len(common_prs)
for count in sorted(reviewer_count_distribution.keys()):
    prs = reviewer_count_distribution[count]
    percentage = (prs / total_prs) * 100
    print(f"  {count} reviewer(s): {prs:2d} PRs ({percentage:4.1f}%)")

print(f"\n🎯 PRs WITH MULTIPLE REVIEWERS:")
print(f"Total PRs with multiple reviewers: {len(multiple_reviewer_examples)}")
print(f"Percentage of multi-reviewer PRs: {(len(multiple_reviewer_examples)/total_prs)*100:.1f}%")

# Show examples of how evaluation handles multiple reviewers
print(f"\n📋 EXAMPLES OF MULTIPLE REVIEWER EVALUATION:")
for i, example in enumerate(multiple_reviewer_examples[:5], 1):
    pr_num = example['pr_number']
    actual = set(example['actual_reviewers'])
    predicted = example['predicted_top3']
    
    # Calculate metrics for this specific PR
    matches_in_top3 = [p for p in predicted if p in actual]
    
    print(f"\n  Example {i}: PR #{pr_num}")
    print(f"    Actual reviewers ({len(actual)}): {', '.join(actual)}")
    print(f"    Predicted top-3: {', '.join(predicted)}")
    print(f"    Matches found: {', '.join(matches_in_top3) if matches_in_top3 else 'None'}")
    print(f"    Hit@3: {'✅ YES' if matches_in_top3 else '❌ NO'}")
    
    # Show how precision/recall calculated for this PR
    if len(predicted) > 0:
        precision_at_3 = len(matches_in_top3) / min(3, len(predicted))
        recall_at_3 = len(matches_in_top3) / len(actual)
        print(f"    Precision@3: {precision_at_3:.3f} ({len(matches_in_top3)}/{min(3, len(predicted))})")
        print(f"    Recall@3: {recall_at_3:.3f} ({len(matches_in_top3)}/{len(actual)})")

print("\n" + "=" * 80)
# Out:
# 🔍 ANALYZING MULTIPLE REVIEWERS IN EVALUATION
# ================================================================================
# 📊 REVIEWER COUNT DISTRIBUTION:
#   1 reviewer(s): 22 PRs (56.4%)
#   2 reviewer(s): 10 PRs (25.6%)
#   3 reviewer(s):  4 PRs (10.3%)
#   4 reviewer(s):  2 PRs ( 5.1%)
#   5 reviewer(s):  1 PRs ( 2.6%)
#
# 🎯 PRs WITH MULTIPLE REVIEWERS:
# Total PRs with multiple reviewers: 17
# Percentage of multi-reviewer PRs: 43.6%
#
# 📋 EXAMPLES OF MULTIPLE REVIEWER EVALUATION:
#
#   Example 1: PR #4612
#     Actual reviewers (2): thorn0, Menelion
#     Predicted top-3: ichernev, petrbela, marwahaha
#     Matches found: None
#     Hit@3: ❌ NO
#     Precision@3: 0.000 (0/3)
#     Recall@3: 0.000 (0/2)
#
#   Example 2: PR #5125
#     Actual reviewers (3): Spiralis, sigurdga, stephenramthun
#     Predicted top-3: ichernev, petrbela, marwahaha
#     Matches found: None
#     Hit@3: ❌ NO
#     Precision@3: 0.000 (0/3)
#     Recall@3: 0.000 (0/3)
#
#   Example 3: PR #5387
#     Actual reviewers (2): avaly, avoinea
#     Predicted top-3: ichernev, petrbela, anandfresh
#     Matches found: None
#     Hit@3: ❌ NO
#     Precision@3: 0.000 (0/3)
#     Recall@3: 0.000 (0/2)
#
#   Example 4: PR #6156
#     Actual reviewers (2): rksp25, anandfresh
#     Predicted top-3: marwahaha, anandfresh, petrbela
#     Matches found: anandfresh
#     Hit@3: ✅ YES
#     Precision@3: 0.333 (1/3)
#     Recall@3: 0.500 (1/2)
#
#   Example 5: PR #5390
#     Actual reviewers (2): jojitoon, anandfresh
#     Predicted top-3: marwahaha, rksp25, petrbela
#     Matches found: None
#     Hit@3: ❌ NO
#     Precision@3: 0.000 (0/3)
#     Recall@3: 0.000 (0/2)
#
# ================================================================================

# %%
# ==================== SAVE METRICS TO JSON ====================
metrics_results = {
    'evaluation_metadata': {
        'total_prs_evaluated': len(common_prs),
        'unique_actual_reviewers': stability['unique_actual_reviewers'],
        'unique_predicted_reviewers': stability['unique_predicted_reviewers']
    },
    'precision_at_k': {
        'precision_at_1': precision_at_1,
        'precision_at_3': precision_at_3,
        'precision_at_5': precision_at_5,
        'precision_at_10': precision_at_10
    },
    'recall_at_k': {
        'recall_at_1': recall_at_1,
        'recall_at_3': recall_at_3,
        'recall_at_5': recall_at_5,
        'recall_at_10': recall_at_10
    },
    'f1_score_at_k': {
        'f1_at_1': f1_at_1,
        'f1_at_3': f1_at_3,
        'f1_at_5': f1_at_5,
        'f1_at_10': f1_at_10
    },
    'hit_rate_at_k': {
        'hit_at_1': hit_at_1,
        'hit_at_3': hit_at_3,
        'hit_at_5': hit_at_5,
        'hit_at_10': hit_at_10
    },
    'mean_reciprocal_rank': {
        'mrr': mrr,
        'mrr_percentage': mrr * 100
    },
    'mean_average_precision_at_k': {
        'map_at_1': map_at_1,
        'map_at_3': map_at_3,
        'map_at_5': map_at_5,
        'map_at_10': map_at_10
    },
    'dcg_at_k': {
        'dcg_at_1': dcg_at_1,
        'dcg_at_3': dcg_at_3,
        'dcg_at_5': dcg_at_5,
        'dcg_at_10': dcg_at_10
    },
    'ndcg_at_k': {
        'ndcg_at_1': ndcg_at_1,
        'ndcg_at_3': ndcg_at_3,
        'ndcg_at_5': ndcg_at_5,
        'ndcg_at_10': ndcg_at_10
    },
    'stability_metrics': {
        'coverage': stability['coverage'],
        'exact_match_rate': stability['exact_match_rate'],
        'diversity_ratio': stability['diversity_ratio']
    }
}

# Save metrics to JSON file
with open('pr_reviewer_evaluation_metrics.json', 'w', encoding='utf-8') as f:
    json.dump(metrics_results, f, indent=2, ensure_ascii=False)

print("✅ Metrics saved to 'pr_reviewer_evaluation_metrics.json'")
# Out:
# ✅ Metrics saved to 'pr_reviewer_evaluation_metrics.json'

# %% [markdown]
# ## 6. Detailed Analysis

# %%
# Analyze correct and incorrect predictions with Top-K evaluation
correct_predictions = []
incorrect_predictions = []
partial_matches = []

for pr_num in sorted(common_prs):
    actual = set(actual_reviewers[pr_num])
    predicted_top3 = predicted_reviewers[pr_num][:3] if predicted_reviewers[pr_num] else []
    
    # Check how many of top-3 predictions match actual reviewers
    matching_predictions = [p for p in predicted_top3 if p in actual]
    
    if matching_predictions:
        # At least one prediction matches
        correct_predictions.append({
            'pr_number': pr_num,
            'actual': list(actual),
            'predicted_top3': predicted_top3,
            'matching_predictions': matching_predictions,
            'match_position': [i+1 for i, p in enumerate(predicted_top3) if p in actual],
            'num_matches': len(matching_predictions)
        })
    else:
        # No predictions match
        incorrect_predictions.append({
            'pr_number': pr_num,
            'actual': list(actual),
            'predicted_top3': predicted_top3,
            'matching_predictions': [],
            'num_matches': 0
        })

print("="*80)
print("📊 TOP-3 PREDICTION ANALYSIS")
print("="*80)
print(f"Total PRs Evaluated: {len(common_prs)}")
print(f"Successful Matched (At least 1 match in top-3): {len(correct_predictions)}")
print(f"Failed to Match (No matches in top-3): {len(incorrect_predictions)}")
print(f"\nTop-3 Hit Rate: {(len(correct_predictions) / len(common_prs)) * 100:.2f}%")
# Out:
# ================================================================================
# 📊 TOP-3 PREDICTION ANALYSIS
# ================================================================================
# Total PRs Evaluated: 39
# Successful Matched (At least 1 match in top-3): 17
# Failed to Match (No matches in top-3): 22
#
# Top-3 Hit Rate: 43.59%

# %% [markdown]
# ## 7. LLM-based Failure Analysis

# %%
import os

def get_pr_details(pr_num):
    """Extract PR details from the loaded data"""
    # Get PR details from predicted data (which has more info)
    for pr in predicted_data['pr_assignments']:
        if pr['pr_number'] == pr_num:
            return {
                'title': pr.get('pr_title', 'N/A'),
                'description': pr.get('pr_requirements', {}).get('description', 'N/A')[:300],  # Limit length
                'labels': pr.get('pr_requirements', {}).get('labels', []),
                'files_changed': pr.get('pr_requirements', {}).get('files_changed', 'N/A'),
                'complexity': pr.get('pr_requirements', {}).get('complexity', 'N/A'),
                'top_3_scores': [
                    f"{r['reviewer_name']} (score: {r.get('match_score', 'N/A')})" 
                    for r in pr.get('top_3_reviewers', [])
                ]
            }
    return None

def analyze_failure_with_llm(failure_info):
    """Use LLM to analyze why a reviewer assignment failed with actual PR context"""
    
    pr_num = failure_info['pr_number']
    actual = failure_info['actual']
    predicted = failure_info['predicted_top3']
    
    # Get actual PR details
    pr_details = get_pr_details(pr_num)
    
    if pr_details:
        prompt = f"""Analyze why this PR reviewer assignment failed to match:

**PR #{pr_num}**
Title: {pr_details['title']}
Description: {pr_details['description']}
Labels: {', '.join(pr_details['labels']) if pr_details['labels'] else 'None'}
Files Changed: {pr_details['files_changed']}
Complexity: {pr_details['complexity']}

**Actual Reviewers Assigned:** {', '.join(actual)}
**Predicted Top 3:** {', '.join(predicted)}

**Top 3 Predictions with Scores:**
{chr(10).join(pr_details['top_3_scores'])}

Based on the PR details above, Provide a concise reason why the actual reviewer was better 
suited than the predicted ones. Focus on the most important factor only. Check the PR properly and avoid generic answers. Also distinguish betwwen the actual and predicted reviewers."""
    
    # Configure environment variables
    os.environ["OPENAI_API_KEY"] = ""
    os.environ["OPENAI_API_BASE"] = "https://openrouter.ai/api/v1"

    llm = ChatOpenAI(
        model="qwen/qwen-2.5-72b-instruct",
        temperature=0.4,  # Slightly higher for more varied responses
        max_tokens=250,
        openai_api_key=os.environ.get("OPENAI_API_KEY"),
        openai_api_base=os.environ.get("OPENAI_API_BASE")
    )

    try:
        response = llm.invoke([HumanMessage(content=prompt)])
        return response.content
    except Exception as e:
        return f"Error: {str(e)}"

# %%
print("🤖 LLM-BASED FAILURE ANALYSIS")

if not incorrect_predictions:
    print("\n✅ All matched!")
else:
    # Analyze all failed predictions
    num_to_analyze = len(incorrect_predictions)
    
    for i in range(num_to_analyze):
        failure = incorrect_predictions[i]
        
        print(f"\n📋 Failure #{i+1}")
        print(f"   PR Number: {failure['pr_number']}")
        print(f"   Actual: {', '.join(failure['actual'])}")
        print(f"   Predicted: {', '.join(failure['predicted_top3'])}")
        print(f"\n   🧠 LLM Analysis:")
        
        analysis = analyze_failure_with_llm(failure)
        
        # Format output
        for line in analysis.split('\n'):
            if line.strip():
                print(f"      {line.strip()}")
# Out:
# 🤖 LLM-BASED FAILURE ANALYSIS
#
# 📋 Failure #1
#    PR Number: 3548
#    Actual: ichernev, icambron, maggiepint, butterflyhug
#    Predicted: anandfresh, marwahaha, cwtuan
#
#    🧠 LLM Analysis:
#       The most important factor in why the actual reviewers (ichernev, icambron, maggiepint, butterflyhug) were better suited than the predicted ones (anandfresh, marwahaha, cwtuan) is their **domain expertise and recent involvement** in the project, particularly in the area of the "Immutable API."
#       **Actual Reviewers:**
#       - **ichernev, icambron, maggiepint, butterflyhug** have likely been actively involved in recent changes and discussions related to the "Immutable API." Their recent contributions and familiarity with the specific codebase and design decisions make them well-suited to provide insightful and relevant feedback on this PR.
#       **Predicted Reviewers:**
#       - **anandfresh, marwahaha, cwtuan** may have less recent involvement or expertise in the "Immutable API" area. While they might be highly skilled and active contributors in other parts of the project, their recent activity and domain knowledge in this specific area are not as strong, making them less optimal choices for this particular PR.
#       In summary, the actual reviewers were better suited due to their recent and relevant domain expertise in the "Immutable API," which is crucial for providing effective and contextually appropriate
#
# 📋 Failure #2
#    PR Number: 3615
#    Actual: jsmreese, marwahaha, ichernev, maggiepint
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The most important factor that explains why the actual reviewers (jsmreese, marwahaha, ichernev, maggiepint) were better suited than the predicted ones (sschueller, anandfresh, carlmrichter) is their **domain expertise and recent activity** in the specific area of the PR, which involves changes to the duration format in the core moment library.
#       ### Domain Expertise and Recent Activity:
#       - **Actual Reviewers:**
#       - **jsmreese, marwahaha, ichernev, maggiepint** have a strong history of contributing to and reviewing changes in the core moment library, particularly in areas related to date and time formatting, including duration formats. Their recent activity and expertise in this specific domain make them well-suited to provide insightful and accurate reviews for this PR.
#       - **Predicted Reviewers:**
#       - **sschueller, anandfresh, carlmrichter** have less recent activity and expertise in the specific area of duration formats within the core moment library. While they may be knowledgeable in other areas of the project, their contributions and reviews are less focused on the specific changes introduced in this PR.
#       ### Conclusion:
#       The actual reviewers were better suited
#
# 📋 Failure #3
#    PR Number: 3666
#    Actual: ichernev
#    Predicted: anandfresh, marwahaha, youneshenniwrites
#
#    🧠 LLM Analysis:
#       The actual reviewer, ichernev, was better suited for this PR compared to the predicted reviewers (anandfresh, marwahaha, youneshenniwrites) primarily because of their specific expertise and recent contributions to the calendar function and date handling features in the codebase.
#       **Reason:**
#       - **ichernev** has a strong track record of working on and reviewing PRs related to date and calendar functionalities. This specific PR focuses on the calendar function and its handling of date formats, which aligns closely with ichernev's recent contributions and expertise. Therefore, ichernev is better positioned to provide insightful and relevant feedback on this PR.
#       In contrast, the predicted reviewers, while highly rated, do not have as strong a recent history of involvement in this specific area of the codebase. Their expertise and recent contributions may be more generalized or focused on other features, making them less ideal for this particular PR.
#
# 📋 Failure #4
#    PR Number: 4004
#    Actual: icambron
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The actual reviewer, icambron, was better suited for this PR compared to the predicted reviewers (sschueller, anandfresh, carlmrichter) because icambron has a history of reviewing and merging locale-related changes in the moment.js project. This specific PR involves adding a Gujarati locale, which is a localization task. icambron's expertise in handling locale-related PRs makes them the most appropriate choice for ensuring the accuracy and consistency of the new locale addition.
#       In contrast, the predicted reviewers, while having high scores, may not have the specific experience or focus on locale-related contributions, making icambron the better match for this particular PR.
#
# 📋 Failure #5
#    PR Number: 4470
#    Actual: marwahaha
#    Predicted: anandfresh, DiscoNova, yulodl
#
#    🧠 LLM Analysis:
#       The actual reviewer, **marwahaha**, was better suited for this PR compared to the predicted reviewers because **marwahaha** has a strong history of reviewing and contributing to PRs related to date and time formatting, particularly in the context of ISO8601 standards. This specific expertise aligns closely with the PR's focus on adding support for the [YYYY] format as an ISO8601 standard, making **marwahaha** the most appropriate choice for ensuring the quality and correctness of the implementation.
#       In contrast, the predicted reviewers **anandfresh**, **DiscoNova**, and **yulodl** have less specialized experience in this particular domain, which makes them less ideal for this specific PR. While they may have contributed to other areas of the project, their expertise does not align as closely with the specific requirements of this PR.
#
# 📋 Failure #6
#    PR Number: 4612
#    Actual: Menelion, thorn0
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The actual reviewers, Menelion and thorn0, were better suited for this PR because they have a strong history of contributing to and reviewing Ukrainian (uk) locale improvements. The PR specifically focuses on Ukrainian locale enhancements, and Menelion and thorn0 have demonstrated expertise and familiarity with this specific locale, making them the most appropriate reviewers for this particular PR. In contrast, the predicted reviewers (sschueller, anandfresh, carlmrichter) may have higher overall scores for general contributions, but they do not have the specific domain expertise in Ukrainian locale improvements that Menelion and thorn0 possess.
#
# 📋 Failure #7
#    PR Number: 5044
#    Actual: ichernev
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The actual reviewer, **ichernev**, was better suited for this PR compared to the predicted reviewers (**sschueller, anandfresh, carlmrichter**) because **ichernev** has a strong history of working on and reviewing localization-related code changes. The PR in question, which fixes an issue with the `updateLocale` function, is directly related to localization. This specific expertise and experience with localization issues make **ichernev** the most appropriate reviewer for this PR, ensuring that the fix is thoroughly vetted and aligns with the project's localization standards and best practices.
#
# 📋 Failure #8
#    PR Number: 5125
#    Actual: sigurdga, stephenramthun, Spiralis
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The most important factor in why the actual reviewers (sigurdga, stephenramthun, Spiralis) were better suited than the predicted ones (sschueller, anandfresh, carlmrichter) is their specific expertise and involvement in Norwegian and Nynorsk locales.
#       **Reason:**
#       - **Actual Reviewers:**
#       - **sigurdga:** Known for their extensive work and expertise in Norwegian and Nynorsk locales. They have a deep understanding of the linguistic and cultural nuances specific to these languages.
#       - **stephenramthun:** Has a history of contributing to and reviewing PRs related to Norwegian and Nynorsk, ensuring the changes are linguistically and technically sound.
#       - **Spiralis:** Also has a strong track record in handling PRs for Norwegian and Nynorsk, making them well-versed in the specific requirements and standards for these locales.
#       - **Predicted Reviewers:**
#       - **sschueller:** While highly rated, their primary focus is on different locales and areas of the project, making them less familiar with the specific nuances of Norwegian and Nynorsk.
#       - **anandfresh:** Similarly, their expertise lies in other areas of the project, and
#
# 📋 Failure #9
#    PR Number: 5147
#    Actual: ashsearle, grantposell, raghavmac
#    Predicted: anandfresh, DiscoNova, yulodl
#
#    🧠 LLM Analysis:
#       The actual reviewers (ashsearle, grantposell, raghavmac) were better suited for PR #5147 because they have a history of reviewing similar or related features in the codebase, particularly those involving date and time functionalities. The PR adds `isWeekend` support, which is closely related to date and time handling. The actual reviewers likely have more experience and context in this specific domain, making them more appropriate for ensuring the quality and correctness of the implementation.
#       In contrast, the predicted reviewers (anandfresh, DiscoNova, yulodl) may have higher scores in general but lack the specific expertise or recent involvement in date and time-related features. This domain-specific knowledge is crucial for effectively reviewing and providing meaningful feedback on the `isWeekend` feature.
#
# 📋 Failure #10
#    PR Number: 5387
#    Actual: avoinea, avaly
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The actual reviewers, avoinea and avaly, were better suited for this PR because they have a strong background in handling locale-specific changes, particularly for Romanian (ro) content. The PR specifically addresses a fix for the month abbreviation in Romanian, which is a highly localized and language-specific change. avoinea and avaly have likely demonstrated expertise and familiarity with Romanian locale issues in the past, making them the most appropriate reviewers for this particular PR.
#       In contrast, the predicted reviewers (sschueller, anandfresh, carlmrichter) may have higher scores in general contributions but lack the specific domain knowledge or experience with Romanian locale changes. This specialized knowledge is crucial for ensuring the accuracy and cultural appropriateness of the fix, which is why avoinea and avaly were the better match.
#
# 📋 Failure #11
#    PR Number: 5427
#    Actual: ElFadiliY, hamzaboularbah, mehdifracso, muerroui, zawette
#    Predicted: sschueller, anandfresh, ichernev
#
#    🧠 LLM Analysis:
#       The actual reviewers assigned (ElFadiliY, hamzaboularbah, mehdifracso, muerroui, zawette) were better suited for PR #5427 because they are likely more familiar with the Arabic language and specifically the Moroccan dialect (ar-ma). The PR involves fixing a typo in the name of Monday, which is a locale-specific change. The actual reviewers, given their names and likely backgrounds, are more likely to have the necessary linguistic and cultural context to review this change effectively.
#       In contrast, the predicted reviewers (sschueller, anandfresh, ichernev) do not have any apparent connection to the Arabic language or the Moroccan locale, making them less suitable for this specific PR.
#
# 📋 Failure #12
#    PR Number: 5447
#    Actual: hehachris, willin, ulion
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The most important factor that explains why the actual reviewers (hehachris, willin, ulion) were better suited than the predicted ones (sschueller, anandfresh, carlmrichter) is the **domain expertise in the specific locale (zh-cn)**.
#       - **Actual Reviewers (hehachris, willin, ulion):** These reviewers likely have specific expertise or familiarity with the Chinese locale (zh-cn). Given that the PR is focused on improving the "next/prev week" functionality for the zh-cn locale, having reviewers who understand the nuances and requirements of this locale is crucial. This ensures that the changes are culturally and linguistically appropriate and meet the needs of the target audience.
#       - **Predicted Reviewers (sschueller, anandfresh, carlmrichter):** While these reviewers may have strong general expertise in the codebase or related areas, they may not have the specific knowledge or experience with the zh-cn locale. This makes them less suitable for reviewing changes that are highly locale-specific.
#       In summary, the actual reviewers were better suited because they have the necessary domain expertise in the zh-cn locale, which is essential for ensuring the quality and appropriateness of the changes in
#
# 📋 Failure #13
#    PR Number: 5728
#    Actual: marwahaha, PriyaBihani
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The actual reviewers, marwahaha and PriyaBihani, were better suited for this PR compared to the predicted reviewers (sschueller, anandfresh, carlmrichter) because they have a more relevant history of contributions and reviews in the specific area of locale and internationalization (i18n) changes.
#       **Key Factor:**
#       - **marwahaha and PriyaBihani** have a proven track record of working on and reviewing PRs related to locale and internationalization, which directly aligns with the changes made in PR #5728. Their expertise in this domain ensures that they can provide more accurate and contextually relevant feedback, making them the better choice for this specific PR.
#       In contrast, the predicted reviewers (sschueller, anandfresh, carlmrichter) may have higher overall scores in the system, but their contributions and reviews are less focused on the specific area of locale and i18n, making them less suitable for this particular PR.
#
# 📋 Failure #14
#    PR Number: 5766
#    Actual: quantumfs
#    Predicted: anandfresh, marwahaha, DiscoNova
#
#    🧠 LLM Analysis:
#       The actual reviewer, **quantumfs**, was better suited for this PR compared to the predicted reviewers because the PR involves a change related to specifying the length of the `toArray` return type, which is likely a low-level or performance-related change. **quantumfs** has a strong background in system-level and performance-related code, making them well-suited to review such changes. In contrast, the predicted reviewers **anandfresh**, **marwahaha**, and **DiscoNova** are generally more focused on higher-level features, user interfaces, and broader architectural decisions, which are less relevant to this specific PR.
#
# 📋 Failure #15
#    PR Number: 6123
#    Actual: danielschuetter
#    Predicted: anandfresh, marwahaha, cwtuan
#
#    🧠 LLM Analysis:
#       The actual reviewer, **danielschuetter**, was better suited for PR #6123 than the predicted reviewers (anandfresh, marwahaha, cwtuan) because **danielschuetter** has a specific domain expertise or recent involvement in the "Gigwell" project or related codebase. The lack of detailed information in the PR (such as labels, description, and files changed) makes it challenging to determine the exact nature of the changes, but the assignment of danielschuetter suggests that they have a deeper understanding or recent context in the specific area of the code that this PR touches. This domain expertise or recent involvement makes danielschuetter more qualified to provide a thorough and effective review compared to the predicted reviewers who, despite high scores, may not have the same level of recent or specific context.
#
# 📋 Failure #16
#    PR Number: 6129
#    Actual: bs-divy-jain
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The actual reviewer, **bs-divy-jain**, was better suited for this PR compared to the predicted reviewers (**sschueller, anandfresh, carlmrichter**) because **bs-divy-jain** has a specific expertise or recent involvement in handling localization and internationalization (i18n) changes, particularly for the Ukrainian language. This PR involves capitalizing month names in the Ukrainian language, which is a localization task. The actual reviewer's recent contributions or familiarity with similar changes in the Ukrainian locale (uk.js) make them a more appropriate choice for reviewing this specific PR.
#       In contrast, the predicted reviewers, while highly scored, may not have the same level of recent or specific experience with Ukrainian localization, making them less ideal for this particular task.
#
# 📋 Failure #17
#    PR Number: 6176
#    Actual: rksp25
#    Predicted: sschueller, anandfresh, carlmrichter
#
#    🧠 LLM Analysis:
#       The actual reviewer, **rksp25**, was better suited for this PR compared to the predicted reviewers because **rksp25** has a strong history of contributing to and reviewing changes related to localization and internationalization in the project. This specific PR involves updating the Vietnamese locale file to capitalize the first letter of months and weekdays, which is a task that requires a deep understanding of both the locale-specific requirements and the project's localization standards.
#       **rksp25** likely has the necessary expertise and context in handling such localization changes, making them a more appropriate choice for this PR. In contrast, the predicted reviewers, while highly rated, may not have the same level of specialized experience in this particular area of the codebase.
#
# 📋 Failure #18
#    PR Number: 6258
#    Actual: zemlanin
#    Predicted: sschueller, anandfresh, icambron
#
#    🧠 LLM Analysis:
#       The actual reviewer, zemlanin, was better suited for this PR compared to the predicted reviewers (sschueller, anandfresh, icambron) because zemlanin has specific expertise and familiarity with the Ukrainian locale. This PR involves fixing an apostrophe typo in the Ukrainian locale, and zemlanin's knowledge of the language and cultural context ensures that the fix is accurate and appropriate. The predicted reviewers, while generally knowledgeable, do not have the same specialized expertise in the Ukrainian locale, making zemlanin the more appropriate choice for this specific PR.
